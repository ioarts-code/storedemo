# %%
import os
files = [
    'components/config-panel.tsx',
    'components/config-dialog.tsx',
    'components/config-modal.tsx',
]
for f in files:
    path = os.path.join('/workspaces/v0-hygraph-new-storefront', f)
    if os.path.exists(path):
        os.remove(path)
        print(f'Removed {path}')
    else:
        print(f'Not found: {path}')
# Out:
# Removed /workspaces/v0-hygraph-new-storefront/components/config-panel.tsx
# Removed /workspaces/v0-hygraph-new-storefront/components/config-dialog.tsx
# Removed /workspaces/v0-hygraph-new-storefront/components/config-modal.tsx

# %%
import os
path = '/workspaces/v0-hygraph-new-storefront/tmp_delete.ipynb'
if os.path.exists(path):
    os.remove(path)
    print(f'Removed {path}')
else:
    print(f'Notebook not found: {path}')
# Out:
# Removed /workspaces/v0-hygraph-new-storefront/tmp_delete.ipynb
